# %% [markdown]
# # Example query and result for song play analysis.

# %% [markdown]
# #### Setup

# %%
# %load_ext sql

# %%
from time import time
import configparser
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

DWH_DB= config.get("CLUSTER","DB_NAME")
DWH_DB_USER= config.get("CLUSTER","DB_USER")
DWH_DB_PASSWORD= config.get("CLUSTER","DB_PASSWORD")
DWH_PORT = config.get("CLUSTER","DB_PORT")
DWH_ENDPOINT=config.get("CLUSTER","HOST")
DWH_ROLE_ARN=config.get("IAM_ROLE","ARN")

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.cn34gilqj2ub.us-west-2.redshift.amazonaws.com:5439/dwh
# 'Connected: dwhuser@dwh'

# %% [markdown]
# ## Example queries
# ### How many times is the each song played on each a day of the week?

# %%
# %%time
# %%sql
SELECT t.weekday, COUNT(p.songplay_id) as num_songplayed
FROM songplay p
JOIN time t ON (p.start_time = t.start_time)
GROUP BY t.weekday
ORDER BY 2 DESC;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cn34gilqj2ub.us-west-2.redshift.amazonaws.com:5439/dwh
# 7 rows affected.
# CPU times: user 5.14 ms, sys: 143 µs, total: 5.28 ms
# Wall time: 4.62 s
# [(3, 250), (1, 207), (2, 191), (5, 188), (4, 160), (6, 90), (0, 58)]

# %% [markdown]
# ### How many uniquer values of each id column exist in songplay?

# %%
# %%time
# %%sql
SELECT 'user',COUNT(DISTINCT user_id) AS num FROM songplay
UNION ALL
SELECT 'song',COUNT(DISTINCT song_id)  FROM songplay
UNION ALL
SELECT 'artist',COUNT(DISTINCT artist_id)  FROM songplay
UNION ALL
SELECT 'start_time',COUNT(DISTINCT start_time) FROM songplay
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cn34gilqj2ub.us-west-2.redshift.amazonaws.com:5439/dwh
# 4 rows affected.
# CPU times: user 5.49 ms, sys: 84 µs, total: 5.57 ms
# Wall time: 601 ms
# [('artist', 638), ('user', 67), ('start_time', 810), ('song', 672)]

# %% [markdown]
# ### How many times song played for each level?

# %%
# %%time
# %%sql
SELECT u.level, COUNT(p.songplay_id) as num_songplayed
FROM songplay p
JOIN users u ON (p.user_id = u.user_id)
GROUP BY 1
ORDER BY 2 DESC;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cn34gilqj2ub.us-west-2.redshift.amazonaws.com:5439/dwh
# 2 rows affected.
# CPU times: user 4.74 ms, sys: 99 µs, total: 4.84 ms
# Wall time: 4.65 s
# [('paid', 916), ('free', 228)]

# %% [markdown]
# ### What is the popular song and who is the artist?

# %%
# %%time
# %%sql
SELECT a.artist_name, s.title, COUNT(p.songplay_id) as num_songplayed
FROM songplay p
JOIN song s ON (p.song_id = s.song_id)
JOIN artist a ON (p.artist_id = a.artist_id)
GROUP BY 1,2
ORDER BY 3 DESC,1;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cn34gilqj2ub.us-west-2.redshift.amazonaws.com:5439/dwh
# 217 rows affected.
# CPU times: user 6.48 ms, sys: 0 ns, total: 6.48 ms
# Wall time: 5.11 s
# [('Dwight Yoakam', "You're The One", 37),
#  ('Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 9),
#  ('Ron Carter', "I CAN'T GET STARTED", 9),
#  ('B.o.B', "Nothin' On You [feat. Bruno Mars] (Album Version)", 8),
#  ('Usher', "Hey Daddy (Daddy's Home)", 6),
#  ('Kid Cudi', 'Up Up & Away', 5),
#  ('Kid Cudi', 'Make Her Say', 5),
#  ('Counting Crows', 'Mr. Jones', 4),
#  ('Muse', 'Supermassive Black Hole (Album Version)', 4),
#  ('matchbox twenty', 'Unwell (Album Version)', 4),
#  ('Alice In Chains', 'Brother', 3),
#  ('Arctic Monkeys', 'From The Ritz To The Rubble', 3),
#  ('Ben Kweller', 'Magic', 3),
#  ('Black Eyed Peas', 'Magic', 3),
#  ('Black Eyed Peas', "Let's Get It Started", 3),
#  ('Fisher', 'Rianna', 3),
#  ('Linkin Park', 'Given Up (Album Version)', 3),
#  ('Metallica', 'Fade To Black', 3),
#  ('Shakira', 'Pienso En Ti', 3),
#  ('The Human League', 'Human', 3),
#  ('38 Special', 'Caught Up In You', 2),
#  ('Aerosmith', 'Crazy', 2),
#  ('Alice In Chains', 'God Smack', 2),
#  ('Arctic Monkeys', 'Fake Tales Of San Francisco', 2),
#  ('Ashanti', 'VooDoo', 2),
#  ('Coldplay', "Don't Panic", 2),
#  ('David Arkenstone', 'Waterfall (Spirit Of The Rainforest Album Version)', 2),
#  ('Duncan Dhu', 'No Puedo Evitar (Pensar En Ti)', 2),
#  ('Emmy The Great', 'Mia', 2),
#  ('Goldfrapp', 'Beautiful', 2),
#  ('Jack Johnson', 'Monsoon', 2),
#  ('Josh Turner', "What It Ain't", 2),
#  ('Musiq', 'Love', 2),
#  ('New Radicals', 'You Get What You Give', 2),
#  ('OneRepublic', 'Good Life', 2),
#  ('Paramore', 'Emergency (Album Version)', 2),
#  ('Pigeon John', 'Crazy', 2),
#  ('Robert Plant', 'If I Were A Carpenter', 2),
#  ('Slim Dusty', 'Long Black Road', 2),
#  ('Starting Rock Feat. Diva Avari', "Don't Go", 2),
#  ('Stryper', 'Lady', 2),
#  ('Taylor Swift', 'The Way I Loved You', 2),
#  ('The Cardigans', 'Lovefool', 2),
#  ('The Rolling Stones', 'Angie (1993 Digital Remaster)', 2),
#  ('The Smiths', 'Girlfriend In A Coma', 2),
#  ('The Smiths', 'The Boy With The Thorn In His Side', 2),
#  ('The Verve', 'Bitter Sweet Symphony', 2),
#  ('12 Stones', 'Adrenaline', 1),
#  ('AFI', 'Affliction', 1),
#  ('Abstract Rude', 'Nuff Fire', 1),
#  ('Aerosmith', 'Angel', 1),
#  ('Amy Winehouse', 'Valerie', 1),
#  ('Anberlin', 'Dismantle. Repair.', 1),
#  ('Andreas Johnson', 'A Little Bit Of Love', 1),
#  ('Andres Calamaro', 'El Novio Del Olvido', 1),
#  ('Angie Stone', "Wish I Didn't Miss You", 1),
#  ('Anita Ward', 'Ring My Bell', 1),
#  ('Aphex Twin', 'Tha', 1),
#  ('Art Pepper', 'Star Eyes', 1),
#  ('Ashanti', 'No Words', 1),
#  ('Ashbury Heights', 'World Coming Down', 1),
#  ('Basshunter', 'Why', 1),
#  ('Beirut', 'My Night With the Prostitute From Marseille', 1),
#  ('Binary Star', 'Solar Powered', 1),
#  ('Black Eyed Peas', 'On My Own', 1),
#  ('Blink-182', 'All Of This', 1),
#  ('Blink-182', 'A New Hope', 1),
#  ('Blufeld', 'On A Deeper Level', 1),
#  ('Bobby Goldsboro', 'Honey', 1),
#  ('Boys Like Girls featuring Taylor Swift', 'Two Is Better Than One', 1),
#  ('Brand New Disaster', "At Least It's Raining", 1),
#  ('Bruna Caram', 'Meus Sonhos', 1),
#  ('Callenish Circle', 'Forgotten', 1),
#  ('Camera Obscura', 'If Looks Could Kill', 1),
#  ('Cascada', 'Kids In America', 1),
#  ('Cascada', 'Truly_ Madly_ Deeply', 1),
#  ('Cat Stevens', 'Sun / C79', 1),
#  ('Cherise', 'No Good 4 You', 1),
#  ('Cocorosie', 'The Moon Asked The Crow', 1),
#  ('Coldplay', 'One I Love', 1),
#  ('Craig David', 'One More Lie (Standing In The Shadows)', 1),
#  ('Cute Is What We Aim For', 'Risque (Album Version)', 1),
#  ('Daddy Yankee', 'A Lo Clasico', 1),
#  ('Dash Berlin', 'Till The Sky Falls Down', 1),
#  ('Dave Hollister', 'One Woman Man', 1),
#  ('De-Phazz', 'Astrud Astronette', 1),
#  ('Dead Kennedys', 'Halloween', 1),
#  ('Descendents', "I'm Not A Loser", 1),
#  ('Dierks Bentley', 'Settle For A Slowdown', 1),
#  ('Donovan', 'Starfish-On-The-Toast (2008 Digital Remaster)', 1),
#  ('Dr. Alban', 'Born In Africa', 1),
#  ('Dragonforce', 'Revolution Deathsquad (Album Version)', 1),
#  ('Dropkick Murphys', 'Johnny_ I Hardly Knew Ya', 1),
#  ('Duncan Dhu', 'Rozando La Eternidad', 1),
#  ('Efecto Mariposa', 'Por quererte', 1),
#  ('Elena', 'Setanta matins', 1),
#  ('Elisa', "Almeno Tu Nell'Universo", 1),
#  ('Enya', 'Exile', 1),
#  ('Escape The Fate', 'Harder Than You Know', 1),
#  ('Evanescence', 'Missing (Live in Europe)', 1),
#  ('Faithless', 'Drifting Away', 1),
#  ('Fat Freddys Drop', 'The Raft', 1),
#  ('Fergie', 'Voodoo Doll', 1),
#  ('Flobots', 'Handlebars (UK Radio Edit)', 1),
#  ('Foo Fighters', 'Still', 1),
#  ('Foo Fighters', 'Hell', 1),
#  ('Fukkk Offf', 'Love My Shake', 1),
#  ('Fusebox', 'My Everything (Lost In Worship Album Version)', 1),
#  ('Ghostland Observatory', 'Stranger Lover', 1),
#  ('Ghostland Observatory', 'Club Soda (Album)', 1),
#  ('Graham Coxon', "Sorrow's Army", 1),
#  ('Hellogoodbye', 'Shimmy Shimmy Quarter Turn (Take It Back To Square One)', 1),
#  ('Hoobastank', 'Never Saw It Coming', 1),
#  ('Hooligans', 'Szex & KV', 1),
#  ('Horse Feathers', 'Dustbowl', 1),
#  ('Huey Lewis & The News', 'I Want A New Drug', 1),
#  ('Ice Cube', 'It Was A Good Day', 1),
#  ('India.Arie', 'Beautiful Flower', 1),
#  ('Jack Johnson', 'Fortunate Fool', 1),
#  ("Jack's Mannequin", 'The Mixed Tape (Album Version)', 1),
#  ("Jack's Mannequin", 'Spinning (Album Version)', 1),
#  ('Jackson 5', 'Ben', 1),
#  ('Jagged Edge featuring Run of Run DMC', "Let's Get Married", 1),
#  ('Jarabe De Palo', 'En Lo Puro No Hay Futuro', 1),
#  ('Jesper Kyd', 'Ezio In Florence', 1),
#  ('Jim White', 'Still Waters', 1),
#  ('John Mayer', "St. Patrick's Day", 1),
#  ('Julie London', 'Get Set For The Blues', 1),
#  ('Kate Voegele', 'One Way Or Another', 1),
#  ('Katrina & The Waves', 'Walking On Sunshine', 1),
#  ('Katy Perry', "I'm Still Breathing", 1),
#  ('Kenny Garrett', 'The House That Nat Built (Album Version)', 1),
#  ('Keyshia Cole / T.I. / Missy Elliott / Young Dro', 'Let It Go', 1),
#  ('Killswitch Engage', 'In A Dead World (Album Version)', 1),
#  ('LCD Soundsystem', 'Drunk Girls', 1),
#  ('La Fuga', 'Baja por diversion (directo 05)', 1),
#  ('Limi-T 21', 'Estoy Enamorado De Ella (Salsa)', 1),
#  ('Lindisfarne', 'Fog On The Tyne (Live)', 1),
#  ('Linkin Park', 'Crawling (Album Version)', 1),
#  ('Lionel Rogg', 'Die Kunst der Fuge_ BWV 1080 (2007 Digital Remaster): Contrapunctus XVII - Inversus', 1),
#  ('Liquid Tension Experiment', 'Paradigm Shift', 1),
#  ('Los Del Rio', 'Macarena', 1),
#  ('Los Rodriguez', 'Enganchate Conmigo', 1),
#  ('Luis Miguel', 'Suena ("Some Day" end title song "The Hunchback of Notre Dame")', 1),
#  ('Lupe Fiasco feat. Matthew Santos', 'Fighters (feat. Matthew Santos) (Amended Album Version)', 1),
#  ('MC Lars', "It's Not Easy (Being Green) (Featuring Pierre Bouvier Of Simple Plan)", 1),
#  ('Mac Lethal', 'Know it All', 1),
#  ('Mad Flava', 'Wax on Tha Belt (Baby G Gets Biz)', 1),
#  ('Marea', 'Marea (version acustica)', 1),
#  ('Marisa Monte', 'O Xote Das Meninas/Asa Branca/Hino A Sao Jose', 1),
#  ('Maroon 5', 'Harder To Breathe', 1),
#  ('Mayer Hawthorne', 'Shiny & New', 1),
#  ('Metallica', 'Eye Of The Beholder', 1),
#  ('Mia X', 'Thugs Like Me', 1),
#  ('Miguel Morales', 'La Derrota de Un Don Juan', 1),
#  ('Muse', "Can't Take My Eyes Off You", 1),
#  ('Muse', 'The Small Print', 1),
#  ('Neneh Cherry', 'Manchild', 1),
#  ('Nicolai Dunger', 'Our Filmscore', 1),
#  ('No Mercy', "Please Don't Go", 1),
#  ('Nocturnal Rites', 'The Vision', 1),
#  ('O-Zone', 'Despre tine', 1),
#  ('O-Zone', 'Dragostea din tin (ma-ya-hi)', 1),
#  ("Old 97's", 'Timebomb (LP Version)', 1),
#  ('Orishas', 'Atrevido', 1),
#  ('Pantera', 'Planet Caravan (Remastered LP Version)', 1),
#  ('Passenger 10', 'Passenger 10', 1),
#  ('Pearl Jam', 'Not For You', 1),
#  ('Phil Collins', 'Two Hearts', 1),
#  ('Pillar', 'Frontline', 1),
#  ('Placebo', 'English Summer Rain', 1),
#  ('Plies', 'I Am The Club (Explicit Album Version)', 1),
#  ('Plus One', 'You (w/o Organ Version)', 1),
#  ('Prohom', 'Mise En Bouche', 1),
#  ('Radiohead', 'Pop Is Dead', 1),
#  ('Radiohead', '15 Step', 1),
#  ('Radiohead', 'Subterranean Homesick Alien', 1),
#  ('Rammstein', 'Engel', 1),
#  ('Rilo Kiley', 'More Adventurous (Album Version)', 1),
#  ('Sanctus Real', 'Possibilities (The Face Of Love Album Version)', 1),
#  ('School Of Seven Bells', 's.Ada.Licht', 1),
#  ('Screaming Trees', 'Witness', 1),
#  ('Selena', 'Como La Flor (2005 Re-mastering) (Live)', 1),
#  ('Silverchair', 'The Door', 1),
#  ('Skillet', 'Rebirthing (Album Version)', 1),
#  ('Sleater-kinney', 'Jumpers (Album)', 1),
#  ("Sniff 'n' The Tears", "Driver's Seat", 1),
#  ('Soltero', 'Songs Of The Season', 1),
#  ('Sounds from the Ground', 'Where The Wild Things Were', 1),
#  ('Soziedad Alkoholika', 'Va Bien', 1),
#  ('Sparklehorse', 'Marigold', 1),
#  ('Staind', 'Everything Changes (Album Version)', 1),
#  ('Steve Miller Band', 'The Joker', 1),
#  ('Stray Cats', 'Ubangi Stomp', 1),
#  ('Streetlight Manifesto', 'Punk Rock Girl', 1),
#  ('Tego Calderon', "Pa' Que Retozen (Amended Version)", 1),
#  ('Tempa T', 'Next Hype', 1),
#  ('The Airborne Toxic Event', 'Sometime Around Midnight', 1),
#  ('The Audition', 'The Running Man', 1),
#  ('The Black Keys', 'Strange Times', 1),
#  ('The Format', 'Inches And Falling (I Love_ Love) (Live)', 1),
#  ('The Knux', 'Bang! Bang!', 1),
#  ('The Mars Volta', 'Eriatarka', 1),
#  ('The Presets', 'Yippiyo-Ay', 1),
#  ('The Undertones', 'My Perfect Cousin', 1),
#  ('The Waterboys', 'Bury My Heart', 1),
#  ('The Yardbirds', "The Train Kept A Rollin'", 1),
#  ('Thousand Foot Krutch', 'The Invitation', 1),
#  ('Tomcraft', 'Loneliness', 1),
#  ('Tweet', 'Always Will (LP Version)', 1),
#  ('Ulf Wakenius', 'Good Morning Susie Soho', 1),
#  ('Van Halen', 'Panama (Remastered Album Version)', 1),
#  ('Whitesnake', 'Fool For Your Loving', 1),
#  ('Wilco', 'I Am Trying to Break Your Heart', 1),
#  ('Wyclef Jean', 'Something About Mary', 1),
#  ('Yellowcard', 'One Year_ Six Months', 1),
#  ('You Me At Six', 'Always Attract', 1)]
